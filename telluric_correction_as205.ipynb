# %%
# %pylab inline
from astropy.io import fits
import glob
import pandas as pd
from scipy.interpolate import interp1d
from tools.nirspec import divspec, gluespec
import pdb as pdb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# For the date 2011/06/20

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20110620*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20110620*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20110620_0627_spec1d1.fits 1.56946 M-WIDE-AO 4.646994
# AS205_20110620_0627_spec1d2.fits 1.56946 M-WIDE-AO 4.954114
# AS205_20110620_0643_spec1d1.fits 1.49455 M-WIDE-AO 4.646994
# AS205_20110620_0643_spec1d2.fits 1.49455 M-WIDE-AO 4.954114
# AS205_20110620_0651_spec1d1.fits 1.46371 M-WIDE-AO 4.646994
# AS205_20110620_0651_spec1d2.fits 1.46371 M-WIDE-AO 4.954114
#
#
# HR5984_20110620_0616_spec1d1.fits 1.632 M-WIDE-AO 4.646994
# HR5984_20110620_0616_spec1d2.fits 1.632 M-WIDE-AO 4.954114
# HR5984_20110620_0827_spec1d1.fits 1.29801 M-WIDE-AO 4.646994
# HR5984_20110620_0827_spec1d2.fits 1.29801 M-WIDE-AO 4.954114
# HR5984_20110620_1047_spec1d1.fits 1.59525 M-WIDE-AO 4.646994
# HR5984_20110620_1047_spec1d2.fits 1.59525 M-WIDE-AO 4.954114
# HR7141_20110620_1251_spec1d1.fits 1.11419 M-WIDE-AO 4.646994
# HR7141_20110620_1251_spec1d2.fits 1.11419 M-WIDE-AO 4.954114
# HR7178_20110620_1422_spec1d1.fits 1.32159 M-WIDE-AO 4.646994
# ...

# %% [markdown]
# 'M1' = 4.711393 'M3' = 5.023287
#
# 'M2' = 4.646994 'M4' = 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20110620_0627_spec1d1.fits'
stdfile='HR5984_20110620_1047_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.1, dpix=0.82, mode='M0')

srcfile='AS205_20110620_0627_spec1d2.fits'
stdfile='HR5984_20110620_1047_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.28, dpix=0.3, mode='M2')

srcfile='AS205_20110620_0643_spec1d1.fits'
stdfile='HR5984_20110620_1047_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.18, dpix=0.4, mode='M0')

srcfile='AS205_20110620_0643_spec1d2.fits'
stdfile='HR5984_20110620_1047_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.15, dpix=0.25, mode='M2')

srcfile='AS205_20110620_0651_spec1d1.fits'
stdfile='HR5984_20110620_1047_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.05, dpix=0.34, mode='M0')

srcfile='AS205_20110620_0651_spec1d2.fits'
stdfile='HR5984_20110620_1047_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.08, dpix=0.3, mode='M2')
# Out:
# SNR: 10.287119708356357 31.09460596587207 9.060166463931012
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0627_M0_div.fits
# SNR: 5.916867452275215 7.112899631155855 14.179077135350965
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0627_M2_div.fits
# SNR: 13.148556574713453 28.143087893420354 10.664477647640442
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0643_M0_div.fits
# SNR: 5.787200328750516 7.033716474780847 11.0035274112094
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0643_M2_div.fits
# SNR: 8.877067178312243 25.949718841209286 7.527871642940701
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0651_M0_div.fits
# SNR: 5.84154944162372 6.886122617316003 9.51256271883554
# Writing to:  ./divdata/AS205/AS205_HR5984_20110620_0651_M2_div.fits

# %% [markdown]
# For the date 2012/05/12

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20120512*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20120512*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20120512_0911_spec1d1.fits 1.50697 M-WIDE-AO 4.646994
# AS205_20120512_0911_spec1d2.fits 1.50697 M-WIDE-AO 4.954114
# AS205_20120512_0936_spec1d1.fits 1.41147 M-WIDE-AO 4.646994
# AS205_20120512_0936_spec1d2.fits 1.41147 M-WIDE-AO 4.954114
#
#
# HR5712_20120512_1004_spec1d1.fits 1.82419 M-WIDE-AO 4.646994
# HR5712_20120512_1004_spec1d2.fits 1.82419 M-WIDE-AO 4.954114
# HR5984_20120512_1110_spec1d1.fits 1.29767 M-WIDE-AO 4.646994
# HR5984_20120512_1110_spec1d2.fits 1.29767 M-WIDE-AO 4.954114
# HR5984_20120512_1307_spec1d1.fits 1.54281 M-WIDE-AO 4.646994
# HR5984_20120512_1307_spec1d2.fits 1.54281 M-WIDE-AO 4.954114
# HR7141_20120512_1512_spec1d1.fits 1.09788 M-WIDE-AO 4.646994
# HR7141_20120512_1512_spec1d2.fits 1.09788 M-WIDE-AO 4.954114

# %%
outdir = './divdata/AS205/'

srcfile='AS205_20120512_0911_spec1d1.fits'
stdfile='HR5984_20120512_1307_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.02, dpix=0.16, mode='M0')

srcfile='AS205_20120512_0911_spec1d2.fits'
stdfile='HR5984_20120512_1307_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.08, dpix=0.2, mode='M2')

srcfile='AS205_20120512_0936_spec1d1.fits'
stdfile='HR5984_20120512_1110_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.08, dpix=0.25, mode='M0')

srcfile='AS205_20120512_0936_spec1d2.fits'
stdfile='HR5984_20120512_1110_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.05, dpix=0.2, mode='M2')
# Out:
# SNR: 7.308105341969981 8.51420900576623 38.98016836082316
# Writing to:  ./divdata/AS205/AS205_HR5984_20120512_0936_M2_div.fits

# %% [raw]
# For the date 2012/05/13

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20120513*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20120513*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20120513_0843_spec1d1.fits 1.62997 M-WIDE-AO 4.646994
# AS205_20120513_0843_spec1d2.fits 1.62997 M-WIDE-AO 4.954114
# AS205_20120513_0904_spec1d1.fits 1.52051 M-WIDE-AO 4.646994
# AS205_20120513_0904_spec1d2.fits 1.52051 M-WIDE-AO 4.954114
#
#
# HR5984_20120513_0829_spec1d1.fits 1.71346 M-WIDE-AO 4.646994
# HR5984_20120513_0829_spec1d2.fits 1.71346 M-WIDE-AO 4.954114
# HR5984_20120513_0920_spec1d1.fits 1.45631 M-WIDE-AO 4.646994
# HR5984_20120513_0920_spec1d2.fits 1.45631 M-WIDE-AO 4.954114
# HR5984_20120513_1145_spec1d1.fits 1.3253 M-WIDE-AO 4.646994
# HR5984_20120513_1145_spec1d2.fits 1.3253 M-WIDE-AO 4.954114
# HR7141_20120513_1505_spec1d1.fits 1.09313 M-WIDE-AO 4.646994
# HR7141_20120513_1505_spec1d2.fits 1.09313 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20120513_0843_spec1d1.fits'
stdfile='HR5984_20120513_0829_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.07, dpix=0.35, mode='M0')

srcfile='AS205_20120513_0843_spec1d2.fits'
stdfile='HR5984_20120513_0829_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.05, dpix=0.28, mode='M2')

srcfile='AS205_20120513_0904_spec1d1.fits'
stdfile='HR5984_20120513_0920_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.02, dpix=0.6, mode='M0')

srcfile='AS205_20120513_0904_spec1d2.fits'
stdfile='HR5984_20120513_0920_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.09, dpix=0.2, mode='M2')
# Out:
# SNR: 16.414025416538085 30.404931818903158 4.568035797978304
# Writing to:  ./divdata/AS205/AS205_HR5984_20120513_0843_M0_div.fits
# SNR: 7.035819591393008 8.276884235966474 37.360631647499034
# Writing to:  ./divdata/AS205/AS205_HR5984_20120513_0843_M2_div.fits
# SNR: 16.901349744167494 35.196501875047325 7.51582610041179
# Writing to:  ./divdata/AS205/AS205_HR5984_20120513_0904_M0_div.fits
# SNR: 7.119423290783618 8.13467218052826 38.21088987905894
# Writing to:  ./divdata/AS205/AS205_HR5984_20120513_0904_M2_div.fits

# %% [markdown]
# For the date 2012/07/01

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20120701*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20120701*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20120701_0650_spec1d1.fits 1.3365 M-WIDE-AO 4.646994
# AS205_20120701_0650_spec1d2.fits 1.3365 M-WIDE-AO 4.954114
# AS205_20120701_0758_spec1d1.fits 1.27625 M-WIDE-AO 4.646994
# AS205_20120701_0758_spec1d2.fits 1.27625 M-WIDE-AO 4.954114
#
#
# HR5984_20120701_0622_spec1d1.fits 1.41111 M-WIDE-AO 4.646994
# HR5984_20120701_0622_spec1d2.fits 1.41111 M-WIDE-AO 4.954114
# HR5984_20120701_0959_spec1d1.fits 1.58221 M-WIDE-AO 4.646994
# HR5984_20120701_0959_spec1d2.fits 1.58221 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20120701_0650_spec1d1.fits'
stdfile='HR5984_20120701_0622_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.04, dpix=-0.05, mode='M0')

srcfile='AS205_20120701_0650_spec1d2.fits'
stdfile='HR5984_20120701_0622_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.05, dpix=0.1, mode='M2')

srcfile='AS205_20120701_0758_spec1d1.fits'
stdfile='HR5984_20120701_0622_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.13, dpix=-0.07, mode='M0')

srcfile='AS205_20120701_0758_spec1d2.fits'
stdfile='HR5984_20120701_0622_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.1, dpix=0.1, mode='M2')
# Out:
# SNR: 17.835535238934508 36.68950238949467 5.701903444532968
# Writing to:  ./divdata/AS205/AS205_HR5984_20120701_0650_M0_div.fits
# SNR: 6.749844185164903 8.056425058370849 41.1266857418511
# Writing to:  ./divdata/AS205/AS205_HR5984_20120701_0650_M2_div.fits
# SNR: 17.392536466081246 36.15648530706412 7.032985403940349
# Writing to:  ./divdata/AS205/AS205_HR5984_20120701_0758_M0_div.fits
# SNR: 6.846936308754392 8.140363435454582 37.72776055248007
# Writing to:  ./divdata/AS205/AS205_HR5984_20120701_0758_M2_div.fits

# %% [markdown]
# For the date 2012/07/02

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20120702*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20120702*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20120702_0551_spec1d1.fits 1.50541 M-WIDE-AO 4.646994
# AS205_20120702_0551_spec1d2.fits 1.50541 M-WIDE-AO 4.954114
# AS205_20120702_0609_spec1d1.fits 1.43326 M-WIDE-AO 4.646994
# AS205_20120702_0609_spec1d2.fits 1.43326 M-WIDE-AO 4.954114
#
#
# HR5984_20120702_0528_spec1d1.fits 1.61607 M-WIDE-AO 4.646994
# HR5984_20120702_0735_spec1d1.fits 1.29871 M-WIDE-AO 4.646994
# HR5984_20120702_0735_spec1d2.fits 1.29871 M-WIDE-AO 4.954114
# HR5984_20120702_0959_spec1d1.fits 1.60431 M-WIDE-AO 4.646994
# HR5984_20120702_0959_spec1d2.fits 1.60431 M-WIDE-AO 4.954114
# HR7141_20120702_1300_spec1d1.fits 1.28193 M-WIDE-AO 4.646994
# HR7141_20120702_1300_spec1d2.fits 1.28193 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20120702_0551_spec1d1.fits'
stdfile='HR5984_20120702_0959_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.01, dpix=-0.4, mode='M0')

srcfile='AS205_20120702_0551_spec1d2.fits'
stdfile='HR5984_20120702_0959_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.15, dpix=-0.17, mode='M2')

srcfile='AS205_20120702_0609_spec1d1.fits'
stdfile='HR5984_20120702_0735_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.015, dpix=-0.1, mode='M0')

srcfile='AS205_20120702_0609_spec1d2.fits'
stdfile='HR5984_20120702_0735_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.09, dpix=-0.2, mode='M2')
# Out:
# SNR: 6.362357002699826 7.525989465252172 33.955784630245894
# Writing to:  ./divdata/AS205/AS205_HR5984_20120702_0551_M2_div.fits

# %% [markdown]
# For the date 2013/06/24

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20130624*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20130624*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20130624_0548_spec1d1.fits 1.70276 M-WIDE-AO 4.646994
# AS205_20130624_0548_spec1d2.fits 1.70276 M-WIDE-AO 4.954114
# AS205_20130624_0615_spec1d1.fits 1.54366 M-WIDE-AO 4.646994
# AS205_20130624_0615_spec1d2.fits 1.54366 M-WIDE-AO 4.954114
#
#
# HR5984_20130624_0527_spec1d1.fits 1.85648 KL-AO 4.646994
# HR5984_20130624_0527_spec1d2.fits 1.85648 KL-AO 4.954114
# HR5984_20130624_0728_spec1d1.fits 1.33158 M-WIDE-AO 4.646994
# HR5984_20130624_0728_spec1d2.fits 1.33158 M-WIDE-AO 4.954114
# HR5984_20130624_1004_spec1d1.fits 1.48032 M-WIDE-AO 4.646994
# HR5984_20130624_1004_spec1d2.fits 1.48032 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20130624_0548_spec1d1.fits'
stdfile='HR5984_20130624_0527_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.05, dpix=-0.8, mode='M0')

srcfile='AS205_20130624_0548_spec1d2.fits'
stdfile='HR5984_20130624_0527_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.05, dpix=-0.9, mode='M2')

srcfile='AS205_20130624_0615_spec1d1.fits'
stdfile='HR5984_20130624_1004_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.19, dpix=-0.2, mode='M0')

srcfile='AS205_20130624_0615_spec1d2.fits'
stdfile='HR5984_20130624_1004_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.12, dpix=-0.20, mode='M2')
# Out:
# SNR: 7.77442474419028 8.794282592592396 36.135683185539065
# Writing to:  ./divdata/AS205/AS205_HR5984_20130624_0548_M2_div.fits
# SNR: 7.724606606779307 8.895653425473318 47.067305981767056
# Writing to:  ./divdata/AS205/AS205_HR5984_20130624_0615_M2_div.fits

# %% [markdown]
# For the date 2013/06/25

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20130625*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20130625*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20130625_0548_spec1d1.fits 1.67715 M-WIDE-AO 4.646994
# AS205_20130625_0548_spec1d2.fits 1.67715 M-WIDE-AO 4.954114
# AS205_20130625_0613_spec1d1.fits 1.53368 M-WIDE-AO 4.646994
# AS205_20130625_0613_spec1d2.fits 1.53368 M-WIDE-AO 4.954114
#
#
# HR5984_20130625_0530_spec1d1.fits 1.7979 M-WIDE-AO 4.646994
# HR5984_20130625_0530_spec1d2.fits 1.7979 M-WIDE-AO 4.954114
# HR5984_20130625_0730_spec1d1.fits 1.32424 M-WIDE-AO 4.646994
# HR5984_20130625_0730_spec1d2.fits 1.32424 M-WIDE-AO 4.954114
# HR5984_20130625_1001_spec1d1.fits 1.48119 M-WIDE-AO 4.646994
# HR5984_20130625_1001_spec1d2.fits 1.48119 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20130625_0548_spec1d1.fits'
stdfile='HR5984_20130625_0530_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.015, dpix=-0.3, mode='M0')

srcfile='AS205_20130625_0548_spec1d2.fits'
stdfile='HR5984_20130625_0530_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.13, dpix=-0.4, mode='M2')

srcfile='AS205_20130625_0613_spec1d1.fits'
stdfile='HR5984_20130625_1001_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.01, dpix=-0.1, mode='M0')

srcfile='AS205_20130625_0613_spec1d2.fits'
stdfile='HR5984_20130625_1001_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.05, dpix=-0.4, mode='M2')
# Out:
# SNR: 18.951364740017585 41.69406510355021 6.001084517774919
# Writing to:  ./divdata/AS205/AS205_HR5984_20130625_0548_M0_div.fits
# SNR: 7.851947477889781 9.134253848011314 39.0993178830959
# Writing to:  ./divdata/AS205/AS205_HR5984_20130625_0548_M2_div.fits
# SNR: 15.323939471319024 34.86535349779399 6.969314180152779
# Writing to:  ./divdata/AS205/AS205_HR5984_20130625_0613_M0_div.fits
# SNR: 7.85778427290146 8.933560785608734 40.390529070080305
# Writing to:  ./divdata/AS205/AS205_HR5984_20130625_0613_M2_div.fits

# %% [markdown]
# For the date 2013/06/27

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20130627*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20130627*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20130627_0538_spec1d1.fits 1.69199 M-WIDE-AO 4.646994
# AS205_20130627_0538_spec1d2.fits 1.69199 M-WIDE-AO 4.954114
# AS205_20130627_0557_spec1d1.fits 1.5773 M-WIDE-AO 4.646994
# AS205_20130627_0557_spec1d2.fits 1.5773 M-WIDE-AO 4.954114
#
#
# HR5984_20130627_0527_spec1d1.fits 1.76397 M-WIDE-AO 4.646994
# HR5984_20130627_0527_spec1d2.fits 1.76397 M-WIDE-AO 4.954114
# HR5984_20130627_0722_spec1d1.fits 1.3243 M-WIDE-AO 4.646994
# HR5984_20130627_0722_spec1d2.fits 1.3243 M-WIDE-AO 4.954114
# HR5984_20130627_0937_spec1d1.fits 1.4257 M-WIDE-AO 4.646994
# HR5984_20130627_0937_spec1d2.fits 1.4257 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20130627_0538_spec1d1.fits'
stdfile='HR5984_20130627_0527_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.1, dpix=-0.35, mode='M0')

srcfile='AS205_20130627_0538_spec1d2.fits'
stdfile='HR5984_20130627_0527_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.17, dpix=-0.5, mode='M2')

srcfile='AS205_20130627_0557_spec1d1.fits'
stdfile='HR5984_20130627_0937_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.15, dpix=-0.2, mode='M0')

srcfile='AS205_20130627_0557_spec1d2.fits'
stdfile='HR5984_20130627_0937_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.25, dpix=-0.17, mode='M2')
# Out:
# SNR: 17.16467160777025 34.59308978460688 4.536565155703483
# Writing to:  ./divdata/AS205/AS205_HR5984_20130627_0538_M0_div.fits
# SNR: 7.068592012166402 7.90375177298437 41.04659189282833
# Writing to:  ./divdata/AS205/AS205_HR5984_20130627_0538_M2_div.fits
# SNR: 12.450665429166618 39.15981396004553 10.09521487924005
# Writing to:  ./divdata/AS205/AS205_HR5984_20130627_0557_M0_div.fits
# SNR: 7.039284959866759 8.22011500274393 39.05317283321072
# Writing to:  ./divdata/AS205/AS205_HR5984_20130627_0557_M2_div.fits

# %% [markdown]
# For the date 2013/06/28

# %%
datadir='./data/'
filelistAS=glob.glob(datadir+'AS205*20130628*.fits')
filelistAS.sort()
for i,file in enumerate(filelistAS):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
    
print('\n')
    
filelistHR=glob.glob(datadir+'HR*20130628*.fits')
filelistHR.sort()
for i,file in enumerate(filelistHR):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# AS205_20130628_0550_spec1d1.fits 1.59251 M-WIDE-AO 4.646994
# AS205_20130628_0550_spec1d2.fits 1.59251 M-WIDE-AO 4.954114
# AS205_20130628_0609_spec1d1.fits 1.50035 M-WIDE-AO 4.646994
# AS205_20130628_0609_spec1d2.fits 1.50035 M-WIDE-AO 4.954114
#
#
# HR5984_20130628_0528_spec1d1.fits 1.72524 M-WIDE-AO 4.646994
# HR5984_20130628_0528_spec1d2.fits 1.72524 M-WIDE-AO 4.954114
# HR5984_20130628_0755_spec1d1.fits 1.29788 M-WIDE-AO 4.646994
# HR5984_20130628_0755_spec1d2.fits 1.29788 M-WIDE-AO 4.954114
# HR5984_20130628_0930_spec1d1.fits 1.41772 M-WIDE-AO 4.646994
# HR5984_20130628_0930_spec1d2.fits 1.41772 M-WIDE-AO 4.954114

# %%
outdir='./divdata/AS205/'

srcfile='AS205_20130628_0550_spec1d1.fits'
stdfile='HR5984_20130628_0528_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.09, dpix=-0.2, mode='M0')

srcfile='AS205_20130628_0550_spec1d2.fits'
stdfile='HR5984_20130628_0528_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=-0.03, dpix=-0.3, mode='M2')

srcfile='AS205_20130628_0609_spec1d1.fits'
stdfile='HR5984_20130628_0930_spec1d1.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.1, dpix=-0.1, mode='M0')

srcfile='AS205_20130628_0609_spec1d2.fits'
stdfile='HR5984_20130628_0930_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, outdir, dtau=0.1, dpix=-0.3, mode='M2')
# Out:
# SNR: 20.09071637020223 38.05249017111031 8.224337300086676
# Writing to:  ./divdata/AS205/AS205_HR5984_20130628_0550_M0_div.fits
# SNR: 7.446403888057637 8.55985974100154 33.552879366371904
# Writing to:  ./divdata/AS205/AS205_HR5984_20130628_0550_M2_div.fits
# SNR: 18.780318100730042 33.357150715186705 5.950329116007701
# Writing to:  ./divdata/AS205/AS205_HR5984_20130628_0609_M0_div.fits
# SNR: 7.070106921495722 8.320394885614537 38.563181824119994
# Writing to:  ./divdata/AS205/AS205_HR5984_20130628_0609_M2_div.fits

# %%
as205_20110620_files = ['AS205_HR5984_20110620_0627_M0_div.fits', 'AS205_HR5984_20110620_0627_M2_div.fits', 
                        'AS205_HR5984_20110620_0643_M0_div.fits', 'AS205_HR5984_20110620_0643_M2_div.fits',
                        'AS205_HR5984_20110620_0651_M0_div.fits', 'AS205_HR5984_20110620_0651_M2_div.fits']

as205_20120512_files = ['AS205_HR5984_20120512_0911_M0_div.fits', 'AS205_HR5984_20120512_0911_M2_div.fits',
                        'AS205_HR5984_20120512_0936_M0_div.fits', 'AS205_HR5984_20120512_0936_M2_div.fits']

as205_20120513_files = ['AS205_HR5984_20120513_0843_M0_div.fits', 'AS205_HR5984_20120513_0843_M2_div.fits',
                        'AS205_HR5984_20120513_0904_M0_div.fits', 'AS205_HR5984_20120513_0904_M2_div.fits']

as205_20120701_files = ['AS205_HR5984_20120701_0650_M0_div.fits', 'AS205_HR5984_20120701_0650_M2_div.fits',
                        'AS205_HR5984_20120701_0758_M0_div.fits', 'AS205_HR5984_20120701_0758_M2_div.fits']

as205_20120702_files = ['AS205_HR5984_20120702_0551_M0_div.fits', 'AS205_HR5984_20120702_0551_M2_div.fits',
                        'AS205_HR5984_20120702_0609_M0_div.fits', 'AS205_HR5984_20120702_0609_M2_div.fits']

as205_20130624_files = ['AS205_HR5984_20130624_0548_M0_div.fits', 'AS205_HR5984_20130624_0548_M2_div.fits',
                        'AS205_HR5984_20130624_0615_M0_div.fits', 'AS205_HR5984_20130624_0615_M2_div.fits']

as205_20130625_files = ['AS205_HR5984_20130625_0548_M0_div.fits', 'AS205_HR5984_20130625_0548_M2_div.fits',
                        'AS205_HR5984_20130625_0613_M0_div.fits', 'AS205_HR5984_20130625_0613_M2_div.fits']

as205_20130627_files = ['AS205_HR5984_20130627_0538_M0_div.fits', 'AS205_HR5984_20130627_0538_M2_div.fits',
                        'AS205_HR5984_20130627_0557_M0_div.fits', 'AS205_HR5984_20130627_0557_M2_div.fits']

as205_20130628_files = ['AS205_HR5984_20130628_0550_M0_div.fits', 'AS205_HR5984_20130628_0550_M2_div.fits',
                        'AS205_HR5984_20130628_0609_M0_div.fits', 'AS205_HR5984_20130628_0609_M2_div.fits']

# %%
outdir='./gluedata/AS205/'

(wave,div)=gluespec('./divdata/as205/',as205_20110620_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20120512_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20120513_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20120701_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20120702_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20130624_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20130625_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20130627_files, outdir)
(wave,div)=gluespec('./divdata/as205/',as205_20130628_files, outdir)
# Out:
# Writing to:  ./gluedata/AS205/AS205_20110620_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20120512_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20120513_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20120701_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20120702_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20130624_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20130625_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20130627_glue.fits
# Writing to:  ./gluedata/AS205/AS205_20130628_glue.fits

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20110620_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20120512_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20120513_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20120701_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20120702_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20130624_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20130625_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20130627_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

# %%
hdulist=fits.open('./gluedata/AS205/AS205_20130628_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(311)
ax2=fig.add_subplot(312)
ax3=fig.add_subplot(313)

ax1.plot(data['wave'],data['div'],drawstyle='steps-mid')
ax2.plot(data['wave'],data['std'],drawstyle='steps-mid')

ax3.plot(data['wave'],data['div'],drawstyle='steps-mid')

ax3.set_xlim(4.69, 4.6925)

#4.69, 4.6925
# Out:
# (4.69, 4.6925)

# %%
hdulist20110620=fits.open('./gluedata/AS205/AS205_20110620_glue.fits')
data20110620=hdulist20110620[1].data

hdulist20120512=fits.open('./gluedata/AS205/AS205_20120512_glue.fits')
data20120512=hdulist20120512[1].data

hdulist20120513=fits.open('./gluedata/AS205/AS205_20120513_glue.fits')
data20120513=hdulist20120513[1].data

hdulist20120701=fits.open('./gluedata/AS205/AS205_20120701_glue.fits')
data20120701=hdulist20120701[1].data

hdulist20120702=fits.open('./gluedata/AS205/AS205_20120702_glue.fits')
data20120702=hdulist20120702[1].data

hdulist20130624=fits.open('./gluedata/AS205/AS205_20130624_glue.fits')
data20130624=hdulist20130624[1].data

hdulist20130625=fits.open('./gluedata/AS205/AS205_20130625_glue.fits')
data20130625=hdulist20130625[1].data

hdulist20130627=fits.open('./gluedata/AS205/AS205_20130627_glue.fits')
data20130627=hdulist20130627[1].data

hdulist20130628=fits.open('./gluedata/AS205/AS205_20130628_glue.fits')
data20130628=hdulist20130628[1].data

fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)

ax1.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax1.plot(data20120512['wave'], data20120512['div']+3, drawstyle='steps-mid')
ax1.plot(data20120513['wave'], data20120513['div']+6, drawstyle='steps-mid')
ax1.plot(data20120701['wave'], data20120701['div']+9, drawstyle='steps-mid')
ax1.plot(data20120702['wave'], data20120702['div']+12, drawstyle='steps-mid')
ax1.plot(data20130624['wave'], data20130624['div']+15, drawstyle='steps-mid')
ax1.plot(data20130625['wave'], data20130625['div']+18, drawstyle='steps-mid')
ax1.plot(data20130627['wave'], data20130627['div']+21, drawstyle='steps-mid')
ax1.plot(data20130628['wave'], data20130628['div']+24, drawstyle='steps-mid')

ax2.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax2.plot(data20120512['wave'], data20120512['div']+3, drawstyle='steps-mid')
ax2.plot(data20120513['wave'], data20120513['div']+6, drawstyle='steps-mid')
ax2.plot(data20120701['wave'], data20120701['div']+9, drawstyle='steps-mid')
ax2.plot(data20120702['wave'], data20120702['div']+12, drawstyle='steps-mid')
ax2.plot(data20130624['wave'], data20130624['div']+15, drawstyle='steps-mid')
ax2.plot(data20130625['wave'], data20130625['div']+18, drawstyle='steps-mid')
ax2.plot(data20130627['wave'], data20130627['div']+21, drawstyle='steps-mid')
ax2.plot(data20130628['wave'], data20130628['div']+24, drawstyle='steps-mid')

ax1.set_xlim(4.63, 4.73)
ax2.set_xlim(4.95, 5.05)

ax2.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.yaxis.set_visible(False)

# %%
fig=plt.figure(figsize=(15,25))
ax1=fig.add_subplot(521)
ax2=fig.add_subplot(522)
ax3=fig.add_subplot(523)
ax4=fig.add_subplot(524)
ax5=fig.add_subplot(525)
ax6=fig.add_subplot(526)
ax7=fig.add_subplot(527)
ax8=fig.add_subplot(528)
ax9=fig.add_subplot(529)
ax0=fig.add_subplot(5,2,10)

ax1.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax1.plot(data20120512['wave'], data20120512['div'], drawstyle='steps-mid')
ax1.plot(data20120513['wave'], data20120513['div'], drawstyle='steps-mid')
ax1.plot(data20120701['wave'], data20120701['div'], drawstyle='steps-mid')
ax1.plot(data20120702['wave'], data20120702['div'], drawstyle='steps-mid')
ax1.plot(data20130624['wave'], data20130624['div'], drawstyle='steps-mid')
ax1.plot(data20130625['wave'], data20130625['div'], drawstyle='steps-mid')
ax1.plot(data20130627['wave'], data20130627['div'], drawstyle='steps-mid')
ax1.plot(data20130628['wave'], data20130628['div'], drawstyle='steps-mid')

ax1.set_xlim(4.648, 4.651)
ax1.set_ylim(0.8, 2)

ax2.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax2.plot(data20120512['wave'], data20120512['div']+1, drawstyle='steps-mid')
ax2.plot(data20120513['wave'], data20120513['div']+2, drawstyle='steps-mid')
ax2.plot(data20120701['wave'], data20120701['div']+3, drawstyle='steps-mid')
ax2.plot(data20120702['wave'], data20120702['div']+4, drawstyle='steps-mid')
ax2.plot(data20130624['wave'], data20130624['div']+5, drawstyle='steps-mid')
ax2.plot(data20130625['wave'], data20130625['div']+6, drawstyle='steps-mid')
ax2.plot(data20130627['wave'], data20130627['div']+7, drawstyle='steps-mid')
ax2.plot(data20130628['wave'], data20130628['div']+8, drawstyle='steps-mid')

ax2.set_xlim(4.648, 4.651)
ax2.set_ylim(0, 10)

ax3.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax3.plot(data20120512['wave'], data20120512['div'], drawstyle='steps-mid')
ax3.plot(data20120513['wave'], data20120513['div'], drawstyle='steps-mid')
ax3.plot(data20120701['wave'], data20120701['div'], drawstyle='steps-mid')
ax3.plot(data20120702['wave'], data20120702['div'], drawstyle='steps-mid')
ax3.plot(data20130624['wave'], data20130624['div'], drawstyle='steps-mid')
ax3.plot(data20130625['wave'], data20130625['div'], drawstyle='steps-mid')
ax3.plot(data20130627['wave'], data20130627['div'], drawstyle='steps-mid')
ax3.plot(data20130628['wave'], data20130628['div'], drawstyle='steps-mid')

ax3.set_xlim(4.656, 4.659)
ax3.set_ylim(0.8, 2)

ax4.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax4.plot(data20120512['wave'], data20120512['div']+1, drawstyle='steps-mid')
ax4.plot(data20120513['wave'], data20120513['div']+2, drawstyle='steps-mid')
ax4.plot(data20120701['wave'], data20120701['div']+3, drawstyle='steps-mid')
ax4.plot(data20120702['wave'], data20120702['div']+4, drawstyle='steps-mid')
ax4.plot(data20130624['wave'], data20130624['div']+5, drawstyle='steps-mid')
ax4.plot(data20130625['wave'], data20130625['div']+6, drawstyle='steps-mid')
ax4.plot(data20130627['wave'], data20130627['div']+7, drawstyle='steps-mid')
ax4.plot(data20130628['wave'], data20130628['div']+8, drawstyle='steps-mid')

ax4.set_xlim(4.656, 4.659)
ax4.set_ylim(0, 10)

ax5.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax5.plot(data20120512['wave'], data20120512['div'], drawstyle='steps-mid')
ax5.plot(data20120513['wave'], data20120513['div'], drawstyle='steps-mid')
ax5.plot(data20120701['wave'], data20120701['div'], drawstyle='steps-mid')
ax5.plot(data20120702['wave'], data20120702['div'], drawstyle='steps-mid')
ax5.plot(data20130624['wave'], data20130624['div'], drawstyle='steps-mid')
ax5.plot(data20130625['wave'], data20130625['div'], drawstyle='steps-mid')
ax5.plot(data20130627['wave'], data20130627['div'], drawstyle='steps-mid')
ax5.plot(data20130628['wave'], data20130628['div'], drawstyle='steps-mid')

ax5.set_xlim(4.6817, 4.684)
ax5.set_ylim(0.8, 2)

ax6.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax6.plot(data20120512['wave'], data20120512['div']+1, drawstyle='steps-mid')
ax6.plot(data20120513['wave'], data20120513['div']+2, drawstyle='steps-mid')
ax6.plot(data20120701['wave'], data20120701['div']+3, drawstyle='steps-mid')
ax6.plot(data20120702['wave'], data20120702['div']+4, drawstyle='steps-mid')
ax6.plot(data20130624['wave'], data20130624['div']+5, drawstyle='steps-mid')
ax6.plot(data20130625['wave'], data20130625['div']+6, drawstyle='steps-mid')
ax6.plot(data20130627['wave'], data20130627['div']+7, drawstyle='steps-mid')
ax6.plot(data20130628['wave'], data20130628['div']+8, drawstyle='steps-mid')

ax6.set_xlim(4.6817, 4.684)
ax6.set_ylim(0, 10)

ax7.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax7.plot(data20120512['wave'], data20120512['div'], drawstyle='steps-mid')
ax7.plot(data20120513['wave'], data20120513['div'], drawstyle='steps-mid')
ax7.plot(data20120701['wave'], data20120701['div'], drawstyle='steps-mid')
ax7.plot(data20120702['wave'], data20120702['div'], drawstyle='steps-mid')
ax7.plot(data20130624['wave'], data20130624['div'], drawstyle='steps-mid')
ax7.plot(data20130625['wave'], data20130625['div'], drawstyle='steps-mid')
ax7.plot(data20130627['wave'], data20130627['div'], drawstyle='steps-mid')
ax7.plot(data20130628['wave'], data20130628['div'], drawstyle='steps-mid')

ax7.set_xlim(4.69, 4.6925)
ax7.set_ylim(0.8, 2)

ax8.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax8.plot(data20120512['wave'], data20120512['div']+1, drawstyle='steps-mid')
ax8.plot(data20120513['wave'], data20120513['div']+2, drawstyle='steps-mid')
ax8.plot(data20120701['wave'], data20120701['div']+3, drawstyle='steps-mid')
ax8.plot(data20120702['wave'], data20120702['div']+4, drawstyle='steps-mid')
ax8.plot(data20130624['wave'], data20130624['div']+5, drawstyle='steps-mid')
ax8.plot(data20130625['wave'], data20130625['div']+6, drawstyle='steps-mid')
ax8.plot(data20130627['wave'], data20130627['div']+7, drawstyle='steps-mid')
ax8.plot(data20130628['wave'], data20130628['div']+8, drawstyle='steps-mid')

ax8.set_xlim(4.69, 4.6925)
ax8.set_ylim(0, 10)

ax9.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax9.plot(data20120512['wave'], data20120512['div'], drawstyle='steps-mid')
ax9.plot(data20120513['wave'], data20120513['div'], drawstyle='steps-mid')
ax9.plot(data20120701['wave'], data20120701['div'], drawstyle='steps-mid')
ax9.plot(data20120702['wave'], data20120702['div'], drawstyle='steps-mid')
ax9.plot(data20130624['wave'], data20130624['div'], drawstyle='steps-mid')
ax9.plot(data20130625['wave'], data20130625['div'], drawstyle='steps-mid')
ax9.plot(data20130627['wave'], data20130627['div'], drawstyle='steps-mid')
ax9.plot(data20130628['wave'], data20130628['div'], drawstyle='steps-mid')

ax9.set_xlim(4.698, 4.702)
ax9.set_ylim(0.8, 2.2)

ax0.plot(data20110620['wave'], data20110620['div'], drawstyle='steps-mid')
ax0.plot(data20120512['wave'], data20120512['div']+1, drawstyle='steps-mid')
ax0.plot(data20120513['wave'], data20120513['div']+2, drawstyle='steps-mid')
ax0.plot(data20120701['wave'], data20120701['div']+3, drawstyle='steps-mid')
ax0.plot(data20120702['wave'], data20120702['div']+4, drawstyle='steps-mid')
ax0.plot(data20130624['wave'], data20130624['div']+5, drawstyle='steps-mid')
ax0.plot(data20130625['wave'], data20130625['div']+6, drawstyle='steps-mid')
ax0.plot(data20130627['wave'], data20130627['div']+7, drawstyle='steps-mid')
ax0.plot(data20130628['wave'], data20130628['div']+8, drawstyle='steps-mid')

ax0.set_xlim(4.698, 4.702)
ax0.set_ylim(0, 10)
# Out:
# (0, 10)
